# %%
pip install cufflinks
# Out:
# Requirement already satisfied: cufflinks in /Users/laurenceadams/opt/anaconda3/lib/python3.9/site-packages (0.17.3)
# Requirement already satisfied: ipython>=5.3.0 in /Users/laurenceadams/opt/anaconda3/lib/python3.9/site-packages (from cufflinks) (7.31.1)
# Requirement already satisfied: ipywidgets>=7.0.0 in /Users/laurenceadams/opt/anaconda3/lib/python3.9/site-packages (from cufflinks) (7.6.5)
# Requirement already satisfied: plotly>=4.1.1 in /Users/laurenceadams/opt/anaconda3/lib/python3.9/site-packages (from cufflinks) (5.9.0)
# Requirement already satisfied: setuptools>=34.4.1 in /Users/laurenceadams/opt/anaconda3/lib/python3.9/site-packages (from cufflinks) (63.4.1)
# Requirement already satisfied: pandas>=0.19.2 in /Users/laurenceadams/opt/anaconda3/lib/python3.9/site-packages (from cufflinks) (1.4.4)
# Requirement already satisfied: six>=1.9.0 in /Users/laurenceadams/opt/anaconda3/lib/python3.9/site-packages (from cufflinks) (1.16.0)
# Requirement already satisfied: colorlover>=0.2.1 in /Users/laurenceadams/opt/anaconda3/lib/python3.9/site-packages (from cufflinks) (0.3.0)
# Requirement already satisfied: numpy>=1.9.2 in /Users/laurenceadams/opt/anaconda3/lib/python3.9/site-packages (from cufflinks) (1.21.5)
# Requirement already satisfied: matplotlib-inline in /Users/laurenceadams/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.3.0->cufflinks) (0.1.6)
# Requirement already satisfied: jedi>=0.16 in /Users/laurenceadams/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.3.0->cufflinks) (0.18.1)
# Requirement already satisfied: pickleshare in /Users/laurenceadams/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.3.0->cufflinks) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /Users/laurenceadams/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.3.0->cufflinks) (5.1.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/laurenceadams/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.3.0->cufflinks) (3.0.20)
# Requirement already satisfied: pexpect>4.3 in /Users/laurenceadams/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.3.0->cufflinks) (4.8.0)
# Requirement already satisfied: decorator in /Users/laurenceadams/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.3.0->cufflinks) (5.1.1)
# Requirement already satisfied: appnope in /Users/laurenceadams/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.3.0->cufflinks) (0.1.2)
# Requirement already satisfied: pygments in /Users/laurenceadams/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.3.0->cufflinks) (2.11.2)
# Requirement already satisfied: backcall in /Users/laurenceadams/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.3.0->cufflinks) (0.2.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /Users/laurenceadams/opt/anaconda3/lib/python3.9/site-packages (from ipywidgets>=7.0.0->cufflinks) (0.2.0)
# Requirement already satisfied: nbformat>=4.2.0 in /Users/laurenceadams/opt/anaconda3/lib/python3.9/site-packages (from ipywidgets>=7.0.0->cufflinks) (5.5.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /Users/laurenceadams/opt/anaconda3/lib/python3.9/site-packages (from ipywidgets>=7.0.0->cufflinks) (1.0.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /Users/laurenceadams/opt/anaconda3/lib/python3.9/site-packages (from ipywidgets>=7.0.0->cufflinks) (6.15.2)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /Users/laurenceadams/opt/anaconda3/lib/python3.9/site-packages (from ipywidgets>=7.0.0->cufflinks) (3.5.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/laurenceadams/opt/anaconda3/lib/python3.9/site-packages (from pandas>=0.19.2->cufflinks) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/laurenceadams/opt/anaconda3/lib/python3.9/site-packages (from pandas>=0.19.2->cufflinks) (2022.7.1)
# Requirement already satisfied: tenacity>=6.2.0 in /Users/laurenceadams/opt/anaconda3/lib/python3.9/site-packages (from plotly>=4.1.1->cufflinks) (8.0.1)
# Requirement already satisfied: packaging in /Users/laurenceadams/opt/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (21.3)
# Requirement already satisfied: nest-asyncio in /Users/laurenceadams/opt/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (1.5.5)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Users/laurenceadams/opt/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (7.3.4)
# Requirement already satisfied: debugpy>=1.0 in /Users/laurenceadams/opt/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (1.5.1)
# Requirement already satisfied: tornado>=6.1 in /Users/laurenceadams/opt/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (6.1)
# Requirement already satisfied: psutil in /Users/laurenceadams/opt/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (5.9.0)
# Requirement already satisfied: pyzmq>=17 in /Users/laurenceadams/opt/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (23.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/laurenceadams/opt/anaconda3/lib/python3.9/site-packages (from jedi>=0.16->ipython>=5.3.0->cufflinks) (0.8.3)
# Requirement already satisfied: fastjsonschema in /Users/laurenceadams/opt/anaconda3/lib/python3.9/site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->cufflinks) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in /Users/laurenceadams/opt/anaconda3/lib/python3.9/site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->cufflinks) (4.16.0)
# Requirement already satisfied: jupyter_core in /Users/laurenceadams/opt/anaconda3/lib/python3.9/site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->cufflinks) (4.11.1)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/laurenceadams/opt/anaconda3/lib/python3.9/site-packages (from pexpect>4.3->ipython>=5.3.0->cufflinks) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/laurenceadams/opt/anaconda3/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.3.0->cufflinks) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in /Users/laurenceadams/opt/anaconda3/lib/python3.9/site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (6.4.12)
# Requirement already satisfied: attrs>=17.4.0 in /Users/laurenceadams/opt/anaconda3/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets>=7.0.0->cufflinks) (21.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/laurenceadams/opt/anaconda3/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets>=7.0.0->cufflinks) (0.18.0)
# Requirement already satisfied: entrypoints in /Users/laurenceadams/opt/anaconda3/lib/python3.9/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (0.4)
# Requirement already satisfied: terminado>=0.8.3 in /Users/laurenceadams/opt/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (0.13.1)
# Requirement already satisfied: prometheus-client in /Users/laurenceadams/opt/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (0.14.1)
# Requirement already satisfied: Send2Trash>=1.8.0 in /Users/laurenceadams/opt/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (1.8.0)
# Requirement already satisfied: nbconvert>=5 in /Users/laurenceadams/opt/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (6.4.4)
# Requirement already satisfied: jinja2 in /Users/laurenceadams/opt/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (2.11.3)
# Requirement already satisfied: argon2-cffi in /Users/laurenceadams/opt/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (21.3.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/laurenceadams/opt/anaconda3/lib/python3.9/site-packages (from packaging->ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (3.0.9)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/laurenceadams/opt/anaconda3/lib/python3.9/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (1.5.0)
# Requirement already satisfied: defusedxml in /Users/laurenceadams/opt/anaconda3/lib/python3.9/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (0.7.1)
# Requirement already satisfied: testpath in /Users/laurenceadams/opt/anaconda3/lib/python3.9/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (0.6.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /Users/laurenceadams/opt/anaconda3/lib/python3.9/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (0.8.4)
# Requirement already satisfied: beautifulsoup4 in /Users/laurenceadams/opt/anaconda3/lib/python3.9/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (4.11.1)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /Users/laurenceadams/opt/anaconda3/lib/python3.9/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (0.5.13)
# Requirement already satisfied: jupyterlab-pygments in /Users/laurenceadams/opt/anaconda3/lib/python3.9/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (0.1.2)
# Requirement already satisfied: bleach in /Users/laurenceadams/opt/anaconda3/lib/python3.9/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (4.1.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/laurenceadams/opt/anaconda3/lib/python3.9/site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (2.0.1)
# Requirement already satisfied: argon2-cffi-bindings in /Users/laurenceadams/opt/anaconda3/lib/python3.9/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in /Users/laurenceadams/opt/anaconda3/lib/python3.9/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in /Users/laurenceadams/opt/anaconda3/lib/python3.9/site-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (2.3.1)
# Requirement already satisfied: webencodings in /Users/laurenceadams/opt/anaconda3/lib/python3.9/site-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (0.5.1)
# Requirement already satisfied: pycparser in /Users/laurenceadams/opt/anaconda3/lib/python3.9/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (2.21)
# Note: you may need to restart the kernel to use updated packages.

# %%
import plotly.graph_objects as go
import pandas as pd
import yfinance as yf
import cufflinks as cf
from plotly.offline import iplot
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df = yf.download(
    "TWTR", start="2018-01-01", end="2018-12-31", progress=False, auto_adjust=True
)

qf = cf.QuantFig(
df, title="Twitter's Stock Price",
legend="top", name="Twitter's stock prices in 2018"
)

qf.add_volume()
# By default will use Close column, however we can change this providing the column argument.
# 20 periods = 20 days
qf.add_sma(periods=20, column="Close", color="red")
qf.add_ema(periods=20, color="green")2

qf.iplot()


fig = go.Figure(
    data=go.Candlestick(
        x=df.index, open=df["Open"], high=df["High"], low=df["Low"], close=df["Close"]
    )
)

fig.update_layout(title="Twitter's stock prices in 2018", yaxis_title="Price ($)")
fig.show()
# Out:
# <div>                            <div id="48424155-0c8c-48fd-a9b8-a065851038cc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("48424155-0c8c-48fd-a9b8-a065851038cc")) {                    Plotly.newPlot(                        "48424155-0c8c-48fd-a9b8-a065851038cc",                        [{"marker":{"color":["#808080","#808080","#808080","#17BECF","#17BECF","#808080","#17BECF","#17BECF","#17BECF","#808080","#808080","#808080","#808080","#808080","#808080","#808080","#808080","#17BECF","#17BECF","#17BECF","#17BECF","#17BECF","#808080","#808080","#17BECF","#17BECF","#17BECF","#17BECF","#808080","#17BECF","#17BECF","#808080","#808080","#808080","#17BECF","#808080","#17BECF","#808080","#808080","#17BECF","#17BECF","#17BECF","#17BECF","#808080","#17BECF","#808080","#17BECF","#17BECF","#808080","#17BECF","#808080","#808080","#808080","#808080","#17BECF","#808080","#808080","#17BECF","#808080","#17BECF","#17BECF","#808080","#808080","#17BECF","#17BECF","#808080","#808080","#17BECF","#808080","#808080","#808080","#808080","#17BECF","#808080","#808080","#17BECF","#808080","#808080","#808080","#17BECF","#808080","#17BECF","#808080","#17BECF","#17BECF","#17BECF","#17BECF","#17BECF","#17BECF","#17BECF","#808080","#17BECF","#808080","#17BECF","#808080","#17BECF","#17BECF","#808080","#17BECF","#17BECF","#17BECF","#17BECF","#17BECF","#17BECF","#17BECF","#17BECF","#17BECF","#17BECF","#808080","#17BECF","#17BECF","#17BECF","#17BECF","#17BECF","#808080","#17BECF","#808080","#17BECF","